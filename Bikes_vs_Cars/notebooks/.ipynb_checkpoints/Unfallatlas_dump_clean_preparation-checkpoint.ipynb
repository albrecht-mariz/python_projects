# %%
import pandas as pd
import numpy as np
from pyproj import Proj
from geopy.geocoders import Nominatim
import requests

# %%
df = pd.read_csv("data/Unfallorte2018_LinRef.txt", sep=";")

# %%
#Berlin eg ULAND 11
dfb = df[df["ULAND"].eq(11)]

# %%
dfb = dfb[dfb["IstRad"].eq(1)]

# %%
#dfb contains all accicents with bycicles in Berlin
dfb.shape
# Out:
# (5192, 22)

# %%
dfb.head(1)
# Out:
#         OBJECTID  ULAND  UREGBEZ  UKREIS  UGEMEINDE  UJAHR  UMONAT  USTUNDE  \
# 112746    112747     11        0       3          3   2018       1       15
#
#         UWOCHENTAG  UKATEGORIE  ...  ULICHTVERH  IstRad  IstPKW  IstFuss  \
# 112746           4           3  ...           1       1       0        1
#
#         IstKrad  IstGkfz  IstSonstige  STRZUSTAND                 LINREFX  \
# 112746        0        0            0           1  798261,384899999950000
#
#                         LINREFY
# 112746  5835047,259899999900000
#
# [1 rows x 22 columns]

# %%
dfb['UTMx'] = dfb['LINREFX'].str.replace(',','.') #.astype(float) #.apply(Decimal.from_float) #use apply                                     
dfb['UTMy'] = dfb['LINREFY'].str.replace(',','.')

# %%
dfb = dfb.drop(columns={"LINREFX","LINREFY"})

# %%
dfb.head(1)
# Out:
#         OBJECTID  ULAND  UREGBEZ  UKREIS  UGEMEINDE  UJAHR  UMONAT  USTUNDE  \
# 112746    112747     11        0       3          3   2018       1       15
#
#         UWOCHENTAG  UKATEGORIE  ...  ULICHTVERH  IstRad  IstPKW  IstFuss  \
# 112746           4           3  ...           1       1       0        1
#
#         IstKrad  IstGkfz  IstSonstige  STRZUSTAND                    UTMx  \
# 112746        0        0            0           1  798261.384899999950000
#
#                            UTMy
# 112746  5835047.259899999900000
#
# [1 rows x 22 columns]

# %%
myProj = Proj(proj="utm", zone=32, ellps="WGS84", south=False)

# %%
dfb['lon'], dfb['lat'] = myProj(dfb['UTMx'].values, dfb['UTMy'].values, inverse=True)

# %%
dfb.head(1)
# Out:
#         OBJECTID  ULAND  UREGBEZ  UKREIS  UGEMEINDE  UJAHR  UMONAT  USTUNDE  \
# 112746    112747     11        0       3          3   2018       1       15
#
#         UWOCHENTAG  UKATEGORIE  ...  IstPKW  IstFuss  IstKrad  IstGkfz  \
# 112746           4           3  ...       0        1        0        0
#
#         IstSonstige  STRZUSTAND                    UTMx  \
# 112746            0           1  798261.384899999950000
#
#                            UTMy        lon        lat
# 112746  5835047.259899999900000  13.403228  52.583472
#
# [1 rows x 24 columns]

# %%
dfb.dtypes
# Out:
# OBJECTID         int64
# ULAND            int64
# UREGBEZ          int64
# UKREIS           int64
# UGEMEINDE        int64
# UJAHR            int64
# UMONAT           int64
# USTUNDE          int64
# UWOCHENTAG       int64
# UKATEGORIE       int64
# UART             int64
# UTYP1            int64
# ULICHTVERH       int64
# IstRad           int64
# IstPKW           int64
# IstFuss          int64
# IstKrad          int64
# IstGkfz          int64
# IstSonstige      int64
# STRZUSTAND       int64
# UTMx            object
# UTMy            object
# lon            float64
# lat            float64
# dtype: object

# %%
#Getting the street names
#geolocator = Nominatim(timeout=3)
# Out:
# C:\Users\brecht\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.21.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.

# %%
location = geolocator.reverse("52.486900, 13.357186")
print(location.address)
# Out:
# Kaiser-Wilhelm-Platz, Crellestraße, Schöneberg, Tempelhof-Schöneberg, Berlin, 10827, Deutschland

# %%
#dfb['location'] = dfb.apply(
    #lambda row: geolocator.reverse((row['lat'], row['lon'])), axis=1).RateLimiter(geolocator.geocode, min_delay_seconds=0)

# %%
apikey = "552jChM8TMOdQm7skDaTwtca_Rp_dneoEHhFCMuCUec"

# %%
base_url = ("https://reverse.geocoder.ls.hereapi.com/6.2/reversegeocode.json"
            + "?apiKey=552jChM8TMOdQm7skDaTwtca_Rp_dneoEHhFCMuCUec"
            + "&mode=retrieveAddresses")
coordinates = f"&prox={52.486900},{13.357186}"

# %%
requests.get(base_url + coordinates).json()
# Out:
# {'Response': {'MetaInfo': {'Timestamp': '2020-02-26T10:20:09.304+0000',
#    'NextPageInformation': '2'},
#   'View': [{'_type': 'SearchResultsViewType',
#     'ViewId': 0,
#     'Result': [{'Relevance': 1.0,
#       'Distance': 6.4,
#       'MatchLevel': 'street',
#       'MatchQuality': {'Country': 1.0,
#        'State': 1.0,
#        'County': 1.0,
#        'City': 1.0,
#        'District': 1.0,
#        'Street': [1.0],
#        'PostalCode': 1.0},
#       'Location': {'LocationId': 'NT_3bofxkhVVhy-.-eVkcfOAB_l_64987760_R',
#        'LocationType': 'point',
#        'DisplayPosition': {'Latitude': 52.48685, 'Longitude': 13.35714},
#        'MapView': {'TopLeft': {'Latitude': 52.48685, 'Longitude': 13.35692},
#         'BottomRight': {'Latitude': 52.48659, 'Longitude': 13.35714}},
#        'Address': {'Label': 'Hauptstraße, 10827 Berlin, Deutschland',
#         'Country': 'DEU',
#         'State': 'Berlin',
#         'County': 'Berlin',
#         'City': 'Berlin',
#         'District': 'Schöneberg',
#         'Street': 'Hauptstraße',
#         'PostalCode': '10827',
#         'AdditionalData': [{'value': 'Deutschland', 'key': 'CountryName'},
#          {'value': 'Berlin', 'key': 'StateName'},
#          {'value': 'Berlin', 'key': 'CountyName'}]},
#        'MapReference': {'ReferenceId': '64987760',
#         'Spot': 1.0,
#         'SideOfStreet': 'right',
#         'CountryId': '20147700',
#         'StateId': '20187401',
#         'CountyId': '20187402',
#         'CityId': '20187403',
#         'DistrictId': '20187410'}}},
#      {'Relevance': 1.0,
#       'Distance': 6.4,
#       'MatchLevel': 'street',
#       'MatchQuality': {'Country': 1.0,
#        'State': 1.0,
#        'County': 1.0,
#        'City': 1.0,
#        'District': 1.0,
#        'PostalCode': 1.0},
#       'Location': {'LocationId': 'NT_aPXzbfqEi-11A5VhfyVQvD_l_53475842_R',
#        'LocationType': 'point',
#        'DisplayPosition': {'Latitude': 52.48685, 'Longitude': 13.35714},
#        'MapView': {'TopLeft': {'Latitude': 52.48691, 'Longitude': 13.35696},
#         'BottomRight': {'Latitude': 52.48685, 'Longitude': 13.35714}},
#        'Address': {'Label': '10827 Berlin, Deutschland',
#         'Country': 'DEU',
#         'State': 'Berlin',
#         'County': 'Berlin',
#         'City': 'Berlin',
#         'District': 'Schöneberg',
#         'PostalCode': '10827',
#         'AdditionalData': [{'value': 'Deutschland', 'key': 'CountryName'},
#          {'value': 'Berlin', 'key': 'StateName'},
#          {'value': 'Berlin', 'key': 'CountyName'}]},
#        'MapReference': {'ReferenceId': '53475842',
#         'Spot': 0.0,
#         'SideOfStreet': 'right',
#         'CountryId': '20147700',
#         'StateId': '20187401',
#         'CountyId': '20187402',
#         'CityId': '20187403',
#         'DistrictId': '20187410'}}},
#      {'Relevance': 1.0,
#       'Distance': 17.4,
#       'MatchLevel': 'houseNumber',
#       'MatchQuality': {'Country': 1.0,
#        'State': 1.0,
#        'County': 1.0,
#        'City': 1.0,
#        'District': 1.0,
#        'Street': [1.0],
#        'HouseNumber': 1.0,
#        'PostalCode': 1.0},
#       'MatchType': 'interpolated',
#       'Location': {'LocationId': 'NT_SMvbRlHFd2bQQ30QYF5n1A_1A',
#        'LocationType': 'point',
#        'DisplayPosition': {'Latitude': 52.48678, 'Longitude': 13.35735},
#        'MapView': {'TopLeft': {'Latitude': 52.4879042,
#          'Longitude': 13.3555039},
#         'BottomRight': {'Latitude': 52.4856558, 'Longitude': 13.3591961}},
#        'Address': {'Label': 'Kaiser-Wilhelm-Platz 5, 10827 Berlin, Deutschland',
#         'Country': 'DEU',
#         'State': 'Berlin',
#         'County': 'Berlin',
#         'City': 'Berlin',
#         'District': 'Schöneberg',
#         'Street': 'Kaiser-Wilhelm-Platz',
#         'HouseNumber': '5',
#         'PostalCode': '10827',
#         'AdditionalData': [{'value': 'Deutschland', 'key': 'CountryName'},
#          {'value': 'Berlin', 'key': 'StateName'},
#          {'value': 'Berlin', 'key': 'CountyName'}]},
#        'MapReference': {'ReferenceId': '53475883',
#         'Spot': 0.57,
#         'SideOfStreet': 'right',
#         'CountryId': '20147700',
#         'StateId': '20187401',
#         'CountyId': '20187402',
#         'CityId': '20187403',
#         'DistrictId': '20187410',
#         'AddressId': '168155323',
#         'RoadLinkId': '37946650'}}},
#      {'Relevance': 1.0,
#       'Distance': 18.9,
#       'MatchLevel': 'houseNumber',
#       'MatchQuality': {'Country': 1.0,
#        'State': 1.0,
#        'County': 1.0,
#        'City': 1.0,
#        'District': 1.0,
#        'Street': [1.0],
#        'HouseNumber': 1.0,
#        'PostalCode': 1.0},
#       'MatchType': 'interpolated',
#       'Location': {'LocationId': 'NT_3bofxkhVVhy-.-eVkcfOAB_xcD',
#        'LocationType': 'point',
#        'DisplayPosition': {'Latitude': 52.48706, 'Longitude': 13.35709},
#        'MapView': {'TopLeft': {'Latitude': 52.4881842,
#          'Longitude': 13.3552439},
#         'BottomRight': {'Latitude': 52.4859358, 'Longitude': 13.3589361}},
#        'Address': {'Label': 'Hauptstraße 17, 10827 Berlin, Deutschland',
#         'Country': 'DEU',
#         'State': 'Berlin',
#         'County': 'Berlin',
#         'City': 'Berlin',
#         'District': 'Schöneberg',
#         'Street': 'Hauptstraße',
#         'HouseNumber': '17',
#         'PostalCode': '10827',
#         'AdditionalData': [{'value': 'Deutschland', 'key': 'CountryName'},
#          {'value': 'Berlin', 'key': 'StateName'},
#          {'value': 'Berlin', 'key': 'CountyName'}]},
#        'MapReference': {'ReferenceId': '1092059461',
#         'Spot': 0.35,
#         'SideOfStreet': 'left',
#         'CountryId': '20147700',
#         'StateId': '20187401',
#         'CountyId': '20187402',
#         'CityId': '20187403',
#         'DistrictId': '20187410',
#         'AddressId': '169776281',
#         'RoadLinkId': '406987856'}}},
#      {'Relevance': 1.0,
#       'Distance': 20.5,
#       'MatchLevel': 'houseNumber',
#       'MatchQuality': {'Country': 1.0,
#        'State': 1.0,
#        'County': 1.0,
#        'City': 1.0,
#        'District': 1.0,
#        'Street': [1.0],
#        'HouseNumber': 1.0,
#        'PostalCode': 1.0},
#       'MatchType': 'interpolated',
#       'Location': {'LocationId': 'NT_3bofxkhVVhy-.-eVkcfOAB_xgD',
#        'LocationType': 'point',
#        'DisplayPosition': {'Latitude': 52.48684, 'Longitude': 13.3569},
#        'MapView': {'TopLeft': {'Latitude': 52.4879642,
#          'Longitude': 13.3550539},
#         'BottomRight': {'Latitude': 52.4857158, 'Longitude': 13.3587461}},
#        'Address': {'Label': 'Hauptstraße 18, 10827 Berlin, Deutschland',
#         'Country': 'DEU',
#         'State': 'Berlin',
#         'County': 'Berlin',
#         'City': 'Berlin',
#         'District': 'Schöneberg',
#         'Street': 'Hauptstraße',
#         'HouseNumber': '18',
#         'PostalCode': '10827',
#         'AdditionalData': [{'value': 'Deutschland', 'key': 'CountryName'},
#          {'value': 'Berlin', 'key': 'StateName'},
#          {'value': 'Berlin', 'key': 'CountyName'}]},
#        'MapReference': {'ReferenceId': '544598387',
#         'Spot': 0.87,
#         'SideOfStreet': 'left',
#         'CountryId': '20147700',
#         'StateId': '20187401',
#         'CountyId': '20187402',
#         'CityId': '20187403',
#         'DistrictId': '20187410',
#         'AddressId': '169281156',
#         'RoadLinkId': '37377351'}}},
#      {'Relevance': 1.0,
#       'Distance': 31.3,
#       'MatchLevel': 'houseNumber',
#       'MatchQuality': {'Country': 1.0,
#        'State': 1.0,
#        'County': 1.0,
#        'City': 1.0,
#        'District': 1.0,
#        'Street': [1.0],
#        'HouseNumber': 1.0,
#        'PostalCode': 1.0},
#       'MatchType': 'interpolated',
#       'Location': {'LocationId': 'NT_3bofxkhVVhy-.-eVkcfOAB_xQjN',
#        'LocationType': 'point',
#        'DisplayPosition': {'Latitude': 52.48715, 'Longitude': 13.3574},
#        'MapView': {'TopLeft': {'Latitude': 52.4882742,
#          'Longitude': 13.3555539},
#         'BottomRight': {'Latitude': 52.4860258, 'Longitude': 13.3592461}},
#        'Address': {'Label': 'Hauptstraße 146, 10827 Berlin, Deutschland',
#         'Country': 'DEU',
#         'State': 'Berlin',
#         'County': 'Berlin',
#         'City': 'Berlin',
#         'District': 'Schöneberg',
#         'Street': 'Hauptstraße',
#         'HouseNumber': '146',
#         'PostalCode': '10827',
#         'AdditionalData': [{'value': 'Deutschland', 'key': 'CountryName'},
#          {'value': 'Berlin', 'key': 'StateName'},
#          {'value': 'Berlin', 'key': 'CountyName'}]},
#        'MapReference': {'ReferenceId': '544598385',
#         'Spot': 0.18,
#         'SideOfStreet': 'right',
#         'CountryId': '20147700',
#         'StateId': '20187401',
#         'CountyId': '20187402',
#         'CityId': '20187403',
#         'DistrictId': '20187410',
#         'AddressId': '168600299',
#         'RoadLinkId': '37657157'}}},
#      {'Relevance': 1.0,
#       'Distance': 36.5,
#       'MatchLevel': 'houseNumber',
#       'MatchQuality': {'Country': 1.0,
#        'State': 1.0,
#        'County': 1.0,
#        'City': 1.0,
#        'District': 1.0,
#        'Street': [1.0],
#        'HouseNumber': 1.0,
#        'PostalCode': 1.0},
#       'MatchType': 'interpolated',
#       'Location': {'LocationId': 'NT_SMvbRlHFd2bQQ30QYF5n1A_0A',
#        'LocationType': 'point',
#        'DisplayPosition': {'Latitude': 52.48661, 'Longitude': 13.35744},
#        'MapView': {'TopLeft': {'Latitude': 52.4877342,
#          'Longitude': 13.3555939},
#         'BottomRight': {'Latitude': 52.4854858, 'Longitude': 13.3592861}},
#        'Address': {'Label': 'Kaiser-Wilhelm-Platz 4, 10827 Berlin, Deutschland',
#         'Country': 'DEU',
#         'State': 'Berlin',
#         'County': 'Berlin',
#         'City': 'Berlin',
#         'District': 'Schöneberg',
#         'Street': 'Kaiser-Wilhelm-Platz',
#         'HouseNumber': '4',
#         'PostalCode': '10827',
#         'AdditionalData': [{'value': 'Deutschland', 'key': 'CountryName'},
#          {'value': 'Berlin', 'key': 'StateName'},
#          {'value': 'Berlin', 'key': 'CountyName'}]},
#        'MapReference': {'ReferenceId': '53476061',
#         'Spot': 0.81,
#         'SideOfStreet': 'right',
#         'CountryId': '20147700',
#         'StateId': '20187401',
#         'CountyId': '20187402',
#         'CityId': '20187403',
#         'DistrictId': '20187410',
#         'AddressId': '169120600',
#         'RoadLinkId': '37806548'}}},
#      {'Relevance': 1.0,
#       'Distance': 37.9,
#       'MatchLevel': 'houseNumber',
#       'MatchQuality': {'Country': 1.0,
#        'State': 1.0,
#        'County': 1.0,
#        'City': 1.0,
#        'District': 1.0,
#        'Street': [1.0],
#        'HouseNumber': 1.0,
#        'PostalCode': 1.0},
#       'MatchType': 'interpolated',
#       'Location': {'LocationId': 'NT_6GvIN9OdTFWyU3HEXbDS3C_0gD',
#        'LocationType': 'point',
#        'DisplayPosition': {'Latitude': 52.48683, 'Longitude': 13.35785},
#        'MapView': {'TopLeft': {'Latitude': 52.4879542,
#          'Longitude': 13.3560039},
#         'BottomRight': {'Latitude': 52.4857058, 'Longitude': 13.3596961}},
#        'Address': {'Label': 'Crellestraße 48, 10827 Berlin, Deutschland',
#         'Country': 'DEU',
#         'State': 'Berlin',
#         'County': 'Berlin',
#         'City': 'Berlin',
#         'District': 'Schöneberg',
#         'Street': 'Crellestraße',
#         'HouseNumber': '48',
#         'PostalCode': '10827',
#         'AdditionalData': [{'value': 'Deutschland', 'key': 'CountryName'},
#          {'value': 'Berlin', 'key': 'StateName'},
#          {'value': 'Berlin', 'key': 'CountyName'}]},
#        'MapReference': {'ReferenceId': '53475882',
#         'Spot': 0.08,
#         'SideOfStreet': 'left',
#         'CountryId': '20147700',
#         'StateId': '20187401',
#         'CountyId': '20187402',
#         'CityId': '20187403',
#         'DistrictId': '20187410',
#         'AddressId': '169415824',
#         'RoadLinkId': '37983108'}}},
#      {'Relevance': 1.0,
#       'Distance': 38.2,
#       'MatchLevel': 'street',
#       'MatchQuality': {'Country': 1.0,
#        'State': 1.0,
#        'County': 1.0,
#        'City': 1.0,
#        'District': 1.0,
#        'Street': [1.0],
#        'PostalCode': 1.0},
#       'Location': {'LocationId': 'NT_3ueOUEPtFyGZmoXh2enKFA_l_1231863918_R',
#        'LocationType': 'point',
#        'DisplayPosition': {'Latitude': 52.48668, 'Longitude': 13.35762},
#        'MapView': {'TopLeft': {'Latitude': 52.48668, 'Longitude': 13.35762},
#         'BottomRight': {'Latitude': 52.48661, 'Longitude': 13.35782}},
#        'Address': {'Label': 'Kolonnenstraße, 10827 Berlin, Deutschland',
#         'Country': 'DEU',
#         'State': 'Berlin',
#         'County': 'Berlin',
#         'City': 'Berlin',
#         'District': 'Schöneberg',
#         'Street': 'Kolonnenstraße',
#         'PostalCode': '10827',
#         'AdditionalData': [{'value': 'Deutschland', 'key': 'CountryName'},
#          {'value': 'Berlin', 'key': 'StateName'},
#          {'value': 'Berlin', 'key': 'CountyName'}]},
#        'MapReference': {'ReferenceId': '1231863918',
#         'Spot': 1.0,
#         'SideOfStreet': 'right',
#         'CountryId': '20147700',
#         'StateId': '20187401',
#         'CountyId': '20187402',
#         'CityId': '20187403',
#         'DistrictId': '20187410'}}},
#      {'Relevance': 1.0,
#       'Distance': 38.9,
#       'MatchLevel': 'street',
#       'MatchQuality': {'Country': 1.0,
#        'State': 1.0,
#        'County': 1.0,
#        'City': 1.0,
#        'District': 1.0,
#        'Street': [1.0],
#        'PostalCode': 1.0},
#       'Location': {'LocationId': 'NT_WzE7asVgpWFm3ALB5NEOYB_l_64987759_L',
#        'LocationType': 'point',
#        'DisplayPosition': {'Latitude': 52.48659, 'Longitude': 13.35692},
#        'MapView': {'TopLeft': {'Latitude': 52.48659, 'Longitude': 13.35666},
#         'BottomRight': {'Latitude': 52.48634, 'Longitude': 13.35692}},
#        'Address': {'Label': 'Hauptstraße, 10827 Berlin, Deutschland',
#         'Country': 'DEU',
#         'State': 'Berlin',
#         'County': 'Berlin',
#         'City': 'Berlin',
#         'District': 'Schöneberg',
#         'Street': 'Hauptstraße',
#         'PostalCode': '10827',
#         'AdditionalData': [{'value': 'Deutschland', 'key': 'CountryName'},
#          {'value': 'Berlin', 'key': 'StateName'},
#          {'value': 'Berlin', 'key': 'CountyName'}]},
#        'MapReference': {'ReferenceId': '64987759',
#         'Spot': 1.0,
#         'SideOfStreet': 'left',
#         'CountryId': '20147700',
#         'StateId': '20187401',
#         'CountyId': '20187402',
#         'CityId': '20187403',
#         'DistrictId': '20187410'}}}]}]}}

# %%
address = requests.get(base_url + coordinates).json()

# %%
type(address)
# Out:
# dict

# %%
def get_adress_from_hereapi(lon,lat):
    base = ("https://reverse.geocoder.ls.hereapi.com/6.2/reversegeocode.json"
            + "?apiKey=552jChM8TMOdQm7skDaTwtca_Rp_dneoEHhFCMuCUec"
            + "&mode=retrieveAddresses")
    requestjson = requests.get(base_url+f"&prox={lon},{lat}").json()
    address = requestjson["Response"]["View"][0]["Result"][0]["Location"]["Address"]
        
    return_dict = {'City': "",
                    'District': "",
                    'Street': "",
                    'HouseNumber' : "",
                    'PostalCode': ""}
    
    for categ in return_dict:
        try:
            return_dict[categ] = address[categ]
        except:
            pass
    
    
    return return_dict

# %%
#dfb_ = dfb.head(2).copy().reset_index(drop=True)
dfb = dfb.copy().reset_index(drop=True)

# %%
dfb["address"] = dfb[['lat', 'lon']].apply(lambda x: get_adress_from_hereapi(x[0], x[1]), axis = 1)

# %%
dfb["address"]
# Out:
# 0       {'City': 'Berlin', 'District': 'Niederschönhau...
# 1       {'City': 'Berlin', 'District': 'Prenzlauer Ber...
# 2       {'City': 'Berlin', 'District': 'Friedrichshain...
# 3       {'City': 'Berlin', 'District': 'Mitte', 'Stree...
# 4       {'City': 'Berlin', 'District': 'Niederschönewe...
#                               ...
# 5187    {'City': 'Berlin', 'District': 'Neukölln', 'St...
# 5188    {'City': 'Berlin', 'District': 'Friedrichsfeld...
# 5189    {'City': 'Berlin', 'District': 'Charlottenburg...
# 5190    {'City': 'Berlin', 'District': 'Weißensee', 'S...
# 5191    {'City': 'Berlin', 'District': 'Fennpfuhl', 'S...
# Name: address, Length: 5192, dtype: object

# %%
pd.DataFrame(list(dfb["address"].values))
# Out:
#         City           District                Street HouseNumber PostalCode
# 0     Berlin  Niederschönhausen        Dietzgenstraße         36A      13156
# 1     Berlin    Prenzlauer Berg   Greifswalder Straße          45      10405
# 2     Berlin     Friedrichshain     Frankfurter Allee          87      10247
# 3     Berlin              Mitte      Leipziger Straße                  10117
# 4     Berlin  Niederschöneweide       Schnellerstraße                  12439
# ...      ...                ...                   ...         ...        ...
# 5187  Berlin           Neukölln                                        12053
# 5188  Berlin    Friedrichsfelde  Rummelsburger Straße                  10315
# 5189  Berlin     Charlottenburg                                        10587
# 5190  Berlin          Weißensee         Roelckestraße         107      13088
# 5191  Berlin          Fennpfuhl      Storkower Straße                  10369
#
# [5192 rows x 5 columns]

# %%
dfbb = pd.concat([dfb,pd.DataFrame(list(dfb["address"].values))],axis=1)

# %%
dfbb.to_csv("data/berlin_bike_accidents_2018.csv")

# %%
dfbb.isna().sum()
# Out:
# OBJECTID       0
# ULAND          0
# UREGBEZ        0
# UKREIS         0
# UGEMEINDE      0
# UJAHR          0
# UMONAT         0
# USTUNDE        0
# UWOCHENTAG     0
# UKATEGORIE     0
# UART           0
# UTYP1          0
# ULICHTVERH     0
# IstRad         0
# IstPKW         0
# IstFuss        0
# IstKrad        0
# IstGkfz        0
# IstSonstige    0
# STRZUSTAND     0
# UTMx           0
# UTMy           0
# lon            0
# lat            0
# address        0
# City           0
# District       0
# Street         0
# HouseNumber    0
# PostalCode     0
# dtype: int64

# %%
dfmissing = dfbb[dfbb['Street'].eq("")]

# %%
kast = dfmissing[dfmissing['UKATEGORIE'].eq(1)] #Street = Kastanienalle

# %%
kast[['OBJECTID','IstGkfz']]
# Out:
#       OBJECTID  IstGkfz
# 3880    205035        1

# %%
#"52.486900, 13.357186"
get_adress_from_hereapi(52.486900,13.357186)
# Out:
# {'City': 'Berlin',
#  'District': 'Schöneberg',
#  'Street': 'Hauptstraße',
#  'HouseNumber': '',
#  'PostalCode': '10827'}

# %%
df_berlin = pd.read_csv("data/berlin_bike_accidents_2018_.csv", sep=";")

# %%
df_berlin[df_berlin['OBJECTID'].eq(205035)]
# Out:
#       Unnamed: 0  OBJECTID  ULAND  UREGBEZ  UKREIS  UGEMEINDE  UJAHR  UMONAT  \
# 3880        3880    205035     11        0       3          3   2018       9
#
#       USTUNDE  UWOCHENTAG  ...                         UTMx  \
# 3880       20           7  ...  799.114.868.800.000.000.000
#
#                                UTMy                     lon  \
# 3880  5.830.271.854.499.990.000.000  13.411.482.769.546.200
#
#                          lat  \
# 3880  52.540.199.060.511.600
#
#                                                 address    City  \
# 3880  {'City': 'Berlin', 'District': 'Prenzlauer Ber...  Berlin
#
#              District          Street  HouseNumber  PostalCode
# 3880  Prenzlauer Berg  Kastanienallee          NaN       10435
#
# [1 rows x 31 columns]
